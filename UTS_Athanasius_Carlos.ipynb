# %% [markdown]
# <a href="https://colab.research.google.com/github/Moonrack/uts/blob/main/UTS_Athanasius_Carlos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path="https://raw.githubusercontent.com/Moonrack/uts/main/loan_data.csv"

# %%
df=pd.read_csv(path)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['ApplicantIncome'],inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1508.0       128.0             360.0             1.0
# 1                0.0        66.0             360.0             1.0
# 2             2358.0       120.0             360.0             1.0
# 3                0.0       141.0             360.0             1.0
# 4             1516.0        95.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1         Urban           Y
# 2         Urban           Y
# 3         Urban           Y
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 376    False   False    False       False      False          False
# 377    False   False    False       False      False          False
# 378    False   False    False       False      False          False
# 379    False   False    False       False      False          False
# 380    False   False    False       False      False          False
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                False       False             False           False
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
baris,kolom= df.shape
print(f'Jumlah data ada {baris} record, jumlah fitur ada : {kolom} kolom')
# Out:
# Jumlah data ada 381 record, jumlah fitur ada : 12 kolom

# %%
df.drop(columns=['Credit_History'],inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 0             1508.0       128.0             360.0         Rural           N
# 1                0.0        66.0             360.0         Urban           Y
# 2             2358.0       120.0             360.0         Urban           Y
# 3                0.0       141.0             360.0         Urban           Y
# 4             1516.0        95.0             360.0         Urban           Y

# %%
df.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 51   LP001245    Male     Yes          2  Not Graduate           Yes
# 377  LP002974    Male     Yes          0      Graduate            No
# 241  LP002236    Male     Yes          2      Graduate            No
# 180  LP001926    Male     Yes          0      Graduate            No
# 0    LP001003    Male     Yes          1      Graduate            No
# 301  LP002517    Male     Yes          1  Not Graduate            No
# 262  LP002332    Male     Yes          0  Not Graduate            No
# 131  LP001720    Male     Yes         3+  Not Graduate            No
# 194  LP001993  Female      No          0      Graduate            No
# 103  LP001581    Male     Yes          0  Not Graduate           NaN
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 51              1875.0        97.0             360.0     Semiurban           Y
# ...

# %%
df[df.Self_Employed.isna()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 6    LP001027    Male     Yes          2      Graduate           NaN
# 13   LP001041    Male     Yes          0      Graduate           NaN
# 20   LP001087  Female      No          2      Graduate           NaN
# 72   LP001370    Male      No          0  Not Graduate           NaN
# 75   LP001387  Female     Yes          0      Graduate           NaN
# 76   LP001398    Male      No          0      Graduate           NaN
# 96   LP001546    Male      No          0      Graduate           NaN
# 103  LP001581    Male     Yes          0  Not Graduate           NaN
# 134  LP001732    Male     Yes          2      Graduate           NaN
# 142  LP001768    Male     Yes          0      Graduate           NaN
# 166  LP001883  Female      No          0      Graduate           NaN
# 186  LP001949    Male     Yes         3+      Graduate           NaN
# 217  LP002128    Male     Yes          2      Graduate           NaN
# ...

# %%
df.LoanAmount.mean()
# Out:
# 104.98687664041995

# %%
df.LoanAmount.median()
# Out:
# 110.0

# %%
df.LoanAmount.mode()
# Out:
# 0    120.0
# Name: LoanAmount, dtype: float64

# %%
df.LoanAmount.fillna(df.LoanAmount.mean(), inplace=True)
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.iloc[[6]]
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 6  LP001027   Male     Yes          2  Graduate           NaN
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 6             1840.0       109.0             360.0         Urban           Y

# %%
df.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    271
# N    110
# Name: count, dtype: int64

# %%
df[df.Loan_Status.isna()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Property_Area, Loan_Status]
# Index: []
